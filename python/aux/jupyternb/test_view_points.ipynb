# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./travel_points.csv')
df.head()
# Out:
#    Unnamed: 0    uav1_x    uav1_y    uav1_z     uav2_x    uav2_y    uav2_z  \
# 0           0 -1.947667 -1.914907  2.543351  11.635495 -1.891487  2.297233
# 1           1 -3.030436 -3.010866  3.799622  13.234854 -2.993526  3.298339
# 2           2 -4.372387 -4.348399  6.020016  14.870789 -4.206667  5.603233
# 3           3 -5.711666 -5.689385  7.949298  16.581653 -5.444093  7.650856
# 4           4 -6.863769 -6.830212  9.336786  17.977742 -6.619955  9.060953
#
#       uav3_x     uav3_y    uav3_z  ...    uav6_z     uav7_x     uav7_y  \
# 0   8.296682   8.250069  2.135944  ...  2.742868  -7.408712  -7.307626
# 1   9.922780   9.921743  2.954455  ...  3.139378  -8.025946  -7.949881
# 2  12.576571  12.539440  5.116242  ...  4.591827 -10.852769 -10.837407
# 3  14.404997  14.294234  7.544198  ...  5.658252 -14.571928 -14.495274
# 4  16.132304  16.067952  9.304369  ...  6.737837 -16.627127 -16.504130
#
#      uav7_z    uav8_x     uav8_y    uav8_z     uav9_x     uav9_y    uav9_z
# 0  2.623579 -0.473991 -10.298498  2.782352   6.883887  -7.301671  2.643768
# 1  2.897699 -1.056691 -10.898334  3.051010   7.305796  -7.715774  2.809224
# 2  3.932221 -2.110656 -13.753430  4.438381   8.943233 -10.260663  4.012395
# 3  4.831640 -3.041292 -18.336635  5.625418  10.151729 -14.959792  5.111981
# 4  5.682319 -3.799543 -21.624570  6.590061  10.959923 -17.631825  6.045942
#
# [5 rows x 28 columns]

# %%
fig = plt.figure(figsize=(20,15))

ax = fig.add_subplot(111, projection='3d')
colors = ['red', 'sandybrown', 'grey', 'gold', 'lawngreen', 'turquoise', 'steelblue', 'darkviolet', 'hotpink']
for i in range(9):
    id = i+1
    pts = ax.scatter(df[f'uav{id}_x'], df[f'uav{id}_y'], df[f'uav{id}_z'], marker='.', c=colors[i], label=f'uav{id}')

ax.set_xlabel('x [m]')
ax.set_ylabel('y [m]')
ax.set_zlabel('z [m]')

ax.set_xlim([-100, 100])
ax.set_ylim([-100, 100])
ax.set_zlim([-0, 40])

ax.legend()
plt.show()
